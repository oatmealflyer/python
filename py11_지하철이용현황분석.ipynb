# %% [markdown]
# # 지하철 이용객 분석
# - https://data.busan.go.kr/
# - 승하차 인원정보 검색
# - 일별역별시간대별승하차 파일 받기
# - 최신 csv 파일로 받기 <br>
# - <img src = "attachment:703fa74c-25f5-40af-9da5-ead998907e00.png" width=200>

# %%
import pandas as pd
file_path = './ref/일별역별시간대별승하차인원(2025년1월).csv'
df = pd.read_csv(file_path, encoding='EUC-KR')
df.head() #데이터 5개 가져오기(데이터 잘 가져오나 확인하는 용도)
# data.tail()
# Out:
#    역번호       역명         년월일 요일  구분    합계  01시-02시  02시-03시  03시-04시  04시-05시  \
# 0   95  다대포해수욕장  2025-01-01  수  승차  8126        0        1        0       14
# 1   95  다대포해수욕장  2025-01-01  수  하차  7674        0        1        0        0
# 2   95  다대포해수욕장  2025-01-02  목  승차  4893        1        0        0       21
# 3   95  다대포해수욕장  2025-01-02  목  하차  3965        1        4        0        1
# 4   95  다대포해수욕장  2025-01-03  금  승차  4572        0        0        0       27
#
#    ...  15시-16시  16시-17시  17시-18시  18시-19시  19시-20시  20시-21시  21시-22시  \
# 0  ...      527      498      517      266      170       98       79
# 1  ...      376      357      295      185      132       81       74
# 2  ...      472      364      373      210      159       87       90
# 3  ...      311      339      296      321      239      143       99
# 4  ...      401      300      363      237      139      102       70
#
#    22시-23시  23시-24시  24시-01시
# 0       38       10        0
# 1       50       71       46
# 2       57       13        0
# 3       92       82       49
# 4       69       13        0
#
# [5 rows x 30 columns]

# %%
columns0 = ['num','name','date','week','type','total']
time_col =  [f"{i}~{i+1}H" for i in range(1,24)]
columns = columns0 + time_col +['24~01H']
df.columns = columns
df.head()
# Out:
#    num     name        date week type  total  1~2H  2~3H  3~4H  4~5H  ...  \
# 0   95  다대포해수욕장  2025-01-01    수   승차   8126     0     1     0    14  ...
# 1   95  다대포해수욕장  2025-01-01    수   하차   7674     0     1     0     0  ...
# 2   95  다대포해수욕장  2025-01-02    목   승차   4893     1     0     0    21  ...
# 3   95  다대포해수욕장  2025-01-02    목   하차   3965     1     4     0     1  ...
# 4   95  다대포해수욕장  2025-01-03    금   승차   4572     0     0     0    27  ...
#
#    15~16H  16~17H  17~18H  18~19H  19~20H  20~21H  21~22H  22~23H  23~24H  \
# 0     527     498     517     266     170      98      79      38      10
# 1     376     357     295     185     132      81      74      50      71
# 2     472     364     373     210     159      87      90      57      13
# 3     311     339     296     321     239     143      99      92      82
# 4     401     300     363     237     139     102      70      69      13
#
#    24~01H
# 0       0
# 1      46
# 2       0
# 3      49
# 4       0
#
# [5 rows x 30 columns]

# %%
data=df.groupby(['num','name','date']).sum().reset_index()
# data[data['date'] =='2025-01-01']
data
# Out:
#       num     name        date week  type  total  1~2H  2~3H  3~4H  4~5H  ...  \
# 0      95  다대포해수욕장  2025-01-01   수수  승차하차  15800     0     2     0    14  ...
# 1      95  다대포해수욕장  2025-01-02   목목  승차하차   8858     2     4     0    22  ...
# 2      95  다대포해수욕장  2025-01-03   금금  승차하차   8279     0     0     0    29  ...
# 3      95  다대포해수욕장  2025-01-04   토토  승차하차   8477     0     0     0    18  ...
# 4      95  다대포해수욕장  2025-01-05   일일  승차하차   6912     0     0     0    13  ...
# ...   ...      ...         ...  ...   ...    ...   ...   ...   ...   ...  ...
# 3467  414       안평  2025-01-27   월월  승차하차   2716     0     0     0     5  ...
# 3468  414       안평  2025-01-28   화화  승차하차   1987     2     2     0     2  ...
# 3469  414       안평  2025-01-29   수수  승차하차   1633     0     0     0     2  ...
# 3470  414       안평  2025-01-30   목목  승차하차   2037     0     0     0     4  ...
# 3471  414       안평  2025-01-31   금금  승차하차   3671     0     0     4     4  ...
#
#       15~16H  16~17H  17~18H  18~19H  19~20H  20~21H  21~22H  22~23H  23~24H  \
# 0        903     855     812     451     302     179     153      88      81
# 1        783     703     669     531     398     230     189     149      95
# 2        682     627     663     542     358     231     209     182      92
# 3        839     750     694     447     284     243     231     171      88
# 4        716     652     530     324     242     176     173     111      63
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 3467     224     236     213     161     105     103      70      58      45
# 3468     141     167     135     149      86      78      64      47      32
# 3469     140     143     152     126      67      58      45      38      32
# 3470     169     194     159     165      83      70      54      67      32
# 3471     256     282     318     287     149     108      63      54      54
#
#       24~01H
# 0         46
# 1         49
# 2         53
# 3         68
# 4         32
# ...      ...
# 3467      31
# 3468      27
# 3469      10
# 3470      14
# 3471      26
#
# [3472 rows x 30 columns]

# %%
gdata = data[['name','date','total']]
gdata = gdata.sort_values(by=['name','date'],ascending=[True,True])
gdata.head(10)
# Out:
#      name        date  total
# 1860   가야  2025-01-01   3953
# 1861   가야  2025-01-02   7242
# 1862   가야  2025-01-03   7293
# 1863   가야  2025-01-04   5609
# 1864   가야  2025-01-05   3945
# 1865   가야  2025-01-06   7469
# 1866   가야  2025-01-07   7217
# 1867   가야  2025-01-08   7324
# 1868   가야  2025-01-09   7110
# 1869   가야  2025-01-10   7052

# %%
mdata = gdata.groupby(by="name").sum().reset_index()
tdata = mdata[['name','total']]
tdata
# Out:
#      name    total
# 0      가야   194925
# 1      감전   211937
# 2    강서구청   140162
# 3      개금   442819
# 4      거제   313595
# ..    ...      ...
# 103    토성   436698
# 104    하단  1003733
# 105   해운대   803371
# 106    호포    67287
# 107    화명   577351
#
# [108 rows x 2 columns]

# %%
sdata = tdata.sort_values(by='total',ascending=False)
sdata.head(20)
# Out:
#        name    total
# 70       서면  3626209
# 83       연산  1500575
# 61      부산역  1337149
# 65       사상  1230792
# 36       동래  1089751
# 72     센텀시티  1083780
# 88      자갈치  1070458
# 23       남포  1045512
# 64       부전  1008329
# 104      하단  1003733
# 33       덕천   976080
# 85      온천장   864085
# 74       수영   855145
# 90       장산   827430
# 57       범일   818007
# 105     해운대   803371
# 77       시청   798668
# 5    경성대부경대   764204
# 59      부산대   760441
# 9        교대   729603

# %%
# ! pip install matplotlib

# %%
import matplotlib
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm 

d2_path ="./ref/D2Coding-Ver1.3.2-20180524.ttf"
fm.fontManager.addfont(d2_path)
plt.rcParams["font.family"] = "D2Coding"

# %%
# for font in fm.findSystemFonts():
    # print(font)
#print(plt.rcParmas["font.famil"])

# %%
# !pip install squarify

# %%
import squarify
plt.figure(figsize=(14,5))
squarify.plot(sizes=sdata['total'].iloc[:20],label=sdata['name'].iloc[:20])
plt.rcParams['font.size'] = 8
plt.gca().invert_yaxis()
plt.axis('off')
plt.show()
