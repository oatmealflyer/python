# %% [markdown]
# # 온라인 쇼핑몰 매출관계 분석

# %% [markdown]
# - 국가통계포털 https://kosis.kr/index/index.do
# - 온라인쇼핑몰 판매매체별 /상품군별거래액
# - 합계등을 제외하고 선택(전지전자통신 2020년전후로 분리되어서 미리 합침)
# - 행렬 전환
# - <div style ="display:flex">
#  <img src="attachment:115bae5b-a9a0-4fd7-b2d8-8f7f88556aca.png" width=180>
#  <img src="attachment:1050afe6-514e-48ef-bca4-ffec23c46940.png" width=180>
#  </div>

# %%
import matplotlib
import matplotlib.pyplot as plt 
import matplotlib.font_manager as fm 
# import matplotlib.dates as madates

import pandas as pd 
from datetime
