# %% [markdown]
# # 시각화 모듈 Seaborn(팁문화분석)

# %%
# !pip install seaborn
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/lkjs/.local/lib/python3.10/site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lkjs/.local/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/lkjs/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lkjs/.local/lib/python3.10/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lkjs/.local/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/lkjs/.local/lib/python3.10/site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in /home/lkjs/.local/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/lkjs/.local/lib/python3.10/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/lkjs/.local/lib/python3.10/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lkjs/.local/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/lkjs/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import seaborn as sns

# seaborn에서 제공하는 데이터셋 이름 목록을 출력합니다.
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.font_manager as fm
fontlist = fm.findSystemFonts(fontpaths=None, fontext='ttf')
fontlist
# Out:
# ['/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Bold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansCondensed-Oblique.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansCondensed-BoldOblique.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuMathTeXGyre.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansCondensed-Bold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSans-ExtraLight.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerif-Bold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansMono.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Oblique.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicCodingBold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed-Bold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareB.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansMono-BoldOblique.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSans-BoldOblique.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothic.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerif.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundR.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed-BoldItalic.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerif-BoldItalic.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareR.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundB.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSans-Oblique.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSansCondensed.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed-Italic.ttf',
#  '/usr/share/fonts/truetype/dejavu/DejaVuSerif-Italic.ttf']

# %%
# 리눅스용 폰트 경로 설정
plt.rc('font', family="NanumGothic")
plt.text(0.2, 0.4, "한글", size=100)
# Out:
# Text(0.2, 0.4, '한글')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')

fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.regplot(x='total_bill', y='tip', data=tips, color='blue', scatter_kws={"s":50,"alpha":0.5}, line_kws={"linestyle":"--"}, ax=ax1)
sns.regplot(x='total_bill', y='tip', data=tips, color='blue', scatter_kws={"s":50,"alpha":0.5}, fit_reg=False, ax=ax2)

fig.suptitle("Scatter plots 선형회귀 의 On Off 비교")
ax1.set_title('선형회귀 ON')
ax2.set_title('선형회귀 OFF')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
iris = sns.load_dataset('iris')
sns.pairplot(iris,hue="species",markers=["o","s","D"])
plt.show()

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

sns.boxplot(x="species",y="sepal_length",data=iris,ax=ax1)
sns.violinplot(x="species",y="petal_length",data=iris,hue="species",palette="muted", ax=ax2)
sns.histplot(data=iris,x="petal_length",hue="species",kde=True,element="step",palette="Set2",ax=ax3)
sns.lmplot(x="sepal_length",y="sepal_width",hue="species",data=iris,markers=["o","s","D"],height=6,aspect=1.2)

ax1.set_title("꽃받침 길이와 종의 관계")
ax2.set_title("종에 따른 꽃잎의 길이 분포 ")
ax3.set_title("종에 따른 꽃잎의 길이 분포2")
plt.show()

# %%
sns.violinplot(x="species",y="petal_length",data=iris,hue="species",palette="muted")
plt.title("종에 따른 곷잎의 길이 분포")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
exercise = sns.load_dataset('exercise')
exercise.sample(5)
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 11          11   4  low fat     83  30 min     rest
# 39          39  14  low fat     95   1 min  walking
# 57          57  20   no fat    102   1 min  walking
# 80          80  27   no fat    140  30 min  running
# 61          61  21  low fat     98  15 min  running

# %%
# point plot
plt.figure(figsize=(10,6))
sns.pointplot(x="time",y="pulse",hue="kind",data=exercise,capsize=0.1)
plt.title("심박수와 시간별 운동종류와의 관계")
# Out:
# Text(0.5, 1.0, '심박수와 시간별 운동종류와의 관계')

# %%
# box plot
plt.figure(figsize=(7,4))
sns.boxplot(x='time',y='pulse',hue="kind",data=exercise,palette="Set2")
plt.title("심박수와 시간별 운동종류와의 관계")
# Out:
# Text(0.5, 1.0, '심박수와 시간별 운동종류와의 관계')

# %%
#swarm plot
plt.figure(figsize=(7,4))
sns.swarmplot
